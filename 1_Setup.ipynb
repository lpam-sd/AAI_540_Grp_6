# %%
# !python --version
# Out:
# Python 3.12.9

# %%
# !pip install -r requirements.txt
# Out:
# Collecting albumentations (from -r requirements.txt (line 1))
#   Using cached albumentations-2.0.8-py3-none-any.whl.metadata (43 kB)
# Collecting opencv-python-headless (from -r requirements.txt (line 2))
#   Using cached opencv_python_headless-4.13.0.92-cp37-abi3-manylinux_2_28_x86_64.whl.metadata (19 kB)
# Requirement already satisfied: absl-py==2.4.0 in /opt/conda/lib/python3.12/site-packages (from -r requirements.txt (line 3)) (2.4.0)
# Requirement already satisfied: accelerate==1.12.0 in /opt/conda/lib/python3.12/site-packages (from -r requirements.txt (line 4)) (1.12.0)
# Requirement already satisfied: adagio==0.2.6 in /opt/conda/lib/python3.12/site-packages (from -r requirements.txt (line 5)) (0.2.6)
# Requirement already satisfied: aioboto3==14.3.0 in /opt/conda/lib/python3.12/site-packages (from -r requirements.txt (line 6)) (14.3.0)
# Requirement already satisfied: aiobotocore==2.22.0 in /opt/conda/lib/python3.12/site-packages (from -r requirements.txt (line 7)) (2.22.0)
# Requirement already satisfied: aiofiles==25.1.0 in /opt/conda/lib/python3.12/site-packages (from -r requirements.txt (line 8)) (25.1.0)
# Requirement already satisfied: aiohappyeyeballs==2.6.1 in /opt/conda/lib/python3.12/site-packages (from -r requirements.txt (line 9)) (2.6.1)
# Requirement already satisfied: aiohttp==3.13.3 in /opt/conda/lib/python3.12/site-packages (from -r requirements.txt (line 10)) (3.13.3)
# Requirement already satisfied: aiohttp-cors==0.8.1 in /opt/conda/lib/python3.12/site-packages (from -r requirements.txt (line 11)) (0.8.1)
# Requirement already satisfied: aioitertools==0.13.0 in /opt/conda/lib/python3.12/site-packages (from -r requirements.txt (line 12)) (0.13.0)
# Requirement already satisfied: aiosignal==1.4.0 in /opt/conda/lib/python3.12/site-packages (from -r requirements.txt (line 13)) (1.4.0)
# Requirement already satisfied: aiosqlite==0.19.0 in /opt/conda/lib/python3.12/site-packages (from -r requirements.txt (line 14)) (0.19.0)
# Collecting albucore==0.0.24 (from -r requirements.txt (line 15))
#   Using cached albucore-0.0.24-py3-none-any.whl.metadata (5.3 kB)
# Requirement already satisfied: alembic==1.18.1 in /opt/conda/lib/python3.12/site-packages (from -r requirements.txt (line 17)) (1.18.1)
# Requirement already satisfied: altair==5.5.0 in /opt/conda/lib/python3.12/site-packages (from -r requirements.txt (line 18)) (5.5.0)
# Requirement already satisfied: amazon-q-developer-jupyterlab-ext==3.4.8 in /opt/conda/lib/python3.12/site-packages (from -r requirements.txt (line 19)) (3.4.8)
# Requirement already satisfied: amazon_sagemaker_jupyter_ai_q_developer==1.2.9 in /opt/conda/lib/python3.12/site-packages (from -r requirements.txt (line 20)) (1.2.9)
# Requirement already satisfied: amazon_sagemaker_jupyter_scheduler==3.1.16 in /opt/conda/lib/python3.12/site-packages (from -r requirements.txt (line 21)) (3.1.16)
# Requirement already satisfied: amazon-sagemaker-sql-editor==0.1.20 in /opt/conda/lib/python3.12/site-packages (from -r requirements.txt (line 22)) (0.1.20)
# Requirement already satisfied: amazon-sagemaker-sql-execution==0.1.9 in /opt/conda/lib/python3.12/site-packages (from -r requirements.txt (line 23)) (0.1.9)
# Requirement already satisfied: amazon-sagemaker-sql-magic==0.1.4 in /opt/conda/lib/python3.12/site-packages (from -r requirements.txt (line 24)) (0.1.4)
# Requirement already satisfied: amzn_sagemaker_aiops_jupyterlab_extension==1.0.4 in /opt/conda/lib/python3.12/site-packages (from -r requirements.txt (line 25)) (1.0.4)
# Requirement already satisfied: annotated-doc==0.0.4 in /opt/conda/lib/python3.12/site-packages (from -r requirements.txt (line 26)) (0.0.4)
# Requirement already satisfied: annotated-types==0.7.0 in /opt/conda/lib/python3.12/site-packages (from -r requirements.txt (line 27)) (0.7.0)
# Requirement already satisfied: ansi2html==1.9.2 in /opt/conda/lib/python3.12/site-packages (from -r requirements.txt (line 28)) (1.9.2)
# Requirement already satisfied: ansicolors==1.1.8 in /opt/conda/lib/python3.12/site-packages (from -r requirements.txt (line 29)) (1.1.8)
# Requirement already satisfied: antlr4-python3-runtime==4.9.3 in /opt/conda/lib/python3.12/site-packages (from -r requirements.txt (line 30)) (4.9.3)
# Requirement already satisfied: anyio==4.12.1 in /opt/conda/lib/python3.12/site-packages (from -r requirements.txt (line 31)) (4.12.1)
# Requirement already satisfied: appdirs==1.4.4 in /opt/conda/lib/python3.12/site-packages (from -r requirements.txt (line 32)) (1.4.4)
# Requirement already satisfied: apsw==3.48.0.0 in /opt/conda/lib/python3.12/site-packages (from -r requirements.txt (line 33)) (3.48.0.0)
# Requirement already satisfied: apswutils==0.1.2 in /opt/conda/lib/python3.12/site-packages (from -r requirements.txt (line 34)) (0.1.2)
# Requirement already satisfied: archspec==0.2.5 in /opt/conda/lib/python3.12/site-packages (from -r requirements.txt (line 35)) (0.2.5)
# Requirement already satisfied: argon2-cffi==25.1.0 in /opt/conda/lib/python3.12/site-packages (from -r requirements.txt (line 36)) (25.1.0)
# Requirement already satisfied: argon2-cffi-bindings==25.1.0 in /opt/conda/lib/python3.12/site-packages (from -r requirements.txt (line 37)) (25.1.0)
# Requirement already satisfied: arrow==1.4.0 in /opt/conda/lib/python3.12/site-packages (from -r requirements.txt (line 38)) (1.4.0)
# Requirement already satisfied: asn1crypto==1.5.1 in /opt/conda/lib/python3.12/site-packages (from -r requirements.txt (line 39)) (1.5.1)
# Requirement already satisfied: astroid==4.0.3 in /opt/conda/lib/python3.12/site-packages (from -r requirements.txt (line 40)) (4.0.3)
# Requirement already satisfied: asttokens==3.0.1 in /opt/conda/lib/python3.12/site-packages (from -r requirements.txt (line 41)) (3.0.1)
# Requirement already satisfied: astunparse==1.6.3 in /opt/conda/lib/python3.12/site-packages (from -r requirements.txt (line 42)) (1.6.3)
# Requirement already satisfied: async-lru==2.1.0 in /opt/conda/lib/python3.12/site-packages (from -r requirements.txt (line 43)) (2.1.0)
# Requirement already satisfied: async-timeout==4.0.3 in /opt/conda/lib/python3.12/site-packages (from -r requirements.txt (line 44)) (4.0.3)
# Requirement already satisfied: attrs==23.2.0 in /opt/conda/lib/python3.12/site-packages (from -r requirements.txt (line 45)) (23.2.0)
# Requirement already satisfied: autogluon==1.4.0 in /opt/conda/lib/python3.12/site-packages (from -r requirements.txt (line 46)) (1.4.0)
# Requirement already satisfied: autogluon.common==1.4.0 in /opt/conda/lib/python3.12/site-packages (from -r requirements.txt (line 47)) (1.4.0)
# Requirement already satisfied: autogluon.core==1.4.0 in /opt/conda/lib/python3.12/site-packages (from -r requirements.txt (line 48)) (1.4.0)
# Requirement already satisfied: autogluon.features==1.4.0 in /opt/conda/lib/python3.12/site-packages (from -r requirements.txt (line 49)) (1.4.0)
# Requirement already satisfied: autogluon.multimodal==1.4.0 in /opt/conda/lib/python3.12/site-packages (from -r requirements.txt (line 50)) (1.4.0)
# Requirement already satisfied: autogluon.tabular==1.4.0 in /opt/conda/lib/python3.12/site-packages (from -r requirements.txt (line 51)) (1.4.0)
# Requirement already satisfied: autogluon.timeseries==1.4.0 in /opt/conda/lib/python3.12/site-packages (from -r requirements.txt (line 52)) (1.4.0)
# Requirement already satisfied: autopep8==2.0.4 in /opt/conda/lib/python3.12/site-packages (from -r requirements.txt (line 53)) (2.0.4)
# Requirement already satisfied: autovizwidget==0.23.0 in /opt/conda/lib/python3.12/site-packages (from -r requirements.txt (line 54)) (0.23.0)
# Requirement already satisfied: aws-embedded-metrics==3.3.0 in /opt/conda/lib/python3.12/site-packages (from -r requirements.txt (line 55)) (3.3.0)
# Requirement already satisfied: aws-glue-sessions==1.0.9 in /opt/conda/lib/python3.12/site-packages (from -r requirements.txt (line 56)) (1.0.9)
# Requirement already satisfied: aws-requests-auth==0.4.3 in /opt/conda/lib/python3.12/site-packages (from -r requirements.txt (line 57)) (0.4.3)
# Requirement already satisfied: aws_s3_access_grants_boto3_plugin==1.2.0 in /opt/conda/lib/python3.12/site-packages (from -r requirements.txt (line 58)) (1.2.0)
# Requirement already satisfied: awswrangler==3.15.0 in /opt/conda/lib/python3.12/site-packages (from -r requirements.txt (line 59)) (3.15.0)
# Requirement already satisfied: babel==2.17.0 in /opt/conda/lib/python3.12/site-packages (from -r requirements.txt (line 60)) (2.17.0)
# Requirement already satisfied: bcrypt==5.0.0 in /opt/conda/lib/python3.12/site-packages (from -r requirements.txt (line 61)) (5.0.0)
# Requirement already satisfied: beartype==0.22.9 in /opt/conda/lib/python3.12/site-packages (from -r requirements.txt (line 62)) (0.22.9)
# Requirement already satisfied: beautifulsoup4==4.14.3 in /opt/conda/lib/python3.12/site-packages (from -r requirements.txt (line 63)) (4.14.3)
# Requirement already satisfied: binaryornot==0.4.4 in /opt/conda/lib/python3.12/site-packages (from -r requirements.txt (line 64)) (0.4.4)
# Requirement already satisfied: black==26.1.0 in /opt/conda/lib/python3.12/site-packages (from -r requirements.txt (line 65)) (26.1.0)
# Requirement already satisfied: bleach==6.3.0 in /opt/conda/lib/python3.12/site-packages (from -r requirements.txt (line 66)) (6.3.0)
# Requirement already satisfied: blinker==1.9.0 in /opt/conda/lib/python3.12/site-packages (from -r requirements.txt (line 67)) (1.9.0)
# Requirement already satisfied: blis==1.3.3 in /opt/conda/lib/python3.12/site-packages (from -r requirements.txt (line 68)) (1.3.3)
# Requirement already satisfied: boltons==25.0.0 in /opt/conda/lib/python3.12/site-packages (from -r requirements.txt (line 69)) (25.0.0)
# Requirement already satisfied: boto3==1.37.3 in /opt/conda/lib/python3.12/site-packages (from -r requirements.txt (line 70)) (1.37.3)
# Requirement already satisfied: botocore==1.37.3 in /opt/conda/lib/python3.12/site-packages (from -r requirements.txt (line 71)) (1.37.3)
# Requirement already satisfied: Brotli==1.1.0 in /opt/conda/lib/python3.12/site-packages (from -r requirements.txt (line 72)) (1.1.0)
# Requirement already satisfied: cached-property==1.5.2 in /opt/conda/lib/python3.12/site-packages (from -r requirements.txt (line 73)) (1.5.2)
# Requirement already satisfied: cacheout==0.16.0 in /opt/conda/lib/python3.12/site-packages (from -r requirements.txt (line 74)) (0.16.0)
# Requirement already satisfied: cachetools==5.5.2 in /opt/conda/lib/python3.12/site-packages (from -r requirements.txt (line 75)) (5.5.2)
# Requirement already satisfied: catalogue==2.0.10 in /opt/conda/lib/python3.12/site-packages (from -r requirements.txt (line 76)) (2.0.10)
# Requirement already satisfied: catboost==1.2.7 in /opt/conda/lib/python3.12/site-packages (from -r requirements.txt (line 77)) (1.2.7)
# Requirement already satisfied: certifi==2026.1.4 in /opt/conda/lib/python3.12/site-packages (from -r requirements.txt (line 78)) (2026.1.4)
# Requirement already satisfied: cffi==1.17.1 in /opt/conda/lib/python3.12/site-packages (from -r requirements.txt (line 79)) (1.17.1)
# Requirement already satisfied: chardet==5.2.0 in /opt/conda/lib/python3.12/site-packages (from -r requirements.txt (line 80)) (5.2.0)
# Requirement already satisfied: charset-normalizer==3.4.4 in /opt/conda/lib/python3.12/site-packages (from -r requirements.txt (line 81)) (3.4.4)
# Requirement already satisfied: click==8.3.1 in /opt/conda/lib/python3.12/site-packages (from -r requirements.txt (line 82)) (8.3.1)
# Requirement already satisfied: cloudpathlib==0.23.0 in /opt/conda/lib/python3.12/site-packages (from -r requirements.txt (line 83)) (0.23.0)
# Requirement already satisfied: cloudpickle==3.1.2 in /opt/conda/lib/python3.12/site-packages (from -r requirements.txt (line 84)) (3.1.2)
# Requirement already satisfied: colorama==0.4.6 in /opt/conda/lib/python3.12/site-packages (from -r requirements.txt (line 85)) (0.4.6)
# Requirement already satisfied: coloredlogs==15.0.1 in /opt/conda/lib/python3.12/site-packages (from -r requirements.txt (line 86)) (15.0.1)
# Requirement already satisfied: colorful==0.5.8 in /opt/conda/lib/python3.12/site-packages (from -r requirements.txt (line 87)) (0.5.8)
# Requirement already satisfied: colorlog==6.10.1 in /opt/conda/lib/python3.12/site-packages (from -r requirements.txt (line 88)) (6.10.1)
# Requirement already satisfied: comm==0.2.3 in /opt/conda/lib/python3.12/site-packages (from -r requirements.txt (line 89)) (0.2.3)
# Requirement already satisfied: conda==25.11.1 in /opt/conda/lib/python3.12/site-packages (from -r requirements.txt (line 90)) (25.11.1)
# Requirement already satisfied: conda-libmamba-solver==25.11.0 in /opt/conda/lib/python3.12/site-packages (from -r requirements.txt (line 91)) (25.11.0)
# Requirement already satisfied: conda-package-handling==2.4.0 in /opt/conda/lib/python3.12/site-packages (from -r requirements.txt (line 92)) (2.4.0)
# Requirement already satisfied: conda_package_streaming==0.12.0 in /opt/conda/lib/python3.12/site-packages (from -r requirements.txt (line 93)) (0.12.0)
# Requirement already satisfied: confection==0.1.5 in /opt/conda/lib/python3.12/site-packages (from -r requirements.txt (line 94)) (0.1.5)
# Requirement already satisfied: contextlib2==21.6.0 in /opt/conda/lib/python3.12/site-packages (from -r requirements.txt (line 95)) (21.6.0)
# Requirement already satisfied: contourpy==1.3.3 in /opt/conda/lib/python3.12/site-packages (from -r requirements.txt (line 96)) (1.3.3)
# Requirement already satisfied: cookiecutter==2.6.0 in /opt/conda/lib/python3.12/site-packages (from -r requirements.txt (line 97)) (2.6.0)
# Requirement already satisfied: coreforecast==0.0.16 in /opt/conda/lib/python3.12/site-packages (from -r requirements.txt (line 98)) (0.0.16)
# Requirement already satisfied: croniter==1.4.1 in /opt/conda/lib/python3.12/site-packages (from -r requirements.txt (line 99)) (1.4.1)
# Requirement already satisfied: cryptography==46.0.3 in /opt/conda/lib/python3.12/site-packages (from -r requirements.txt (line 100)) (46.0.3)
# Requirement already satisfied: cycler==0.12.1 in /opt/conda/lib/python3.12/site-packages (from -r requirements.txt (line 101)) (0.12.1)
# Requirement already satisfied: cymem==2.0.13 in /opt/conda/lib/python3.12/site-packages (from -r requirements.txt (line 102)) (2.0.13)
# Requirement already satisfied: cytoolz==1.1.0 in /opt/conda/lib/python3.12/site-packages (from -r requirements.txt (line 103)) (1.1.0)
# Requirement already satisfied: dash==2.18.1 in /opt/conda/lib/python3.12/site-packages (from -r requirements.txt (line 104)) (2.18.1)
# Collecting dash-core-components==2.0.0 (from -r requirements.txt (line 105))
#   Using cached dash_core_components-2.0.0-py3-none-any.whl.metadata (2.9 kB)
# Collecting dash-html-components==2.0.0 (from -r requirements.txt (line 106))
#   Using cached dash_html_components-2.0.0-py3-none-any.whl.metadata (3.8 kB)
# Collecting dash-table==5.0.0 (from -r requirements.txt (line 107))
#   Using cached dash_table-5.0.0-py3-none-any.whl.metadata (2.4 kB)
# Requirement already satisfied: dask==2026.1.1 in /opt/conda/lib/python3.12/site-packages (from -r requirements.txt (line 108)) (2026.1.1)
# Requirement already satisfied: databricks-sdk==0.73.0 in /opt/conda/lib/python3.12/site-packages (from -r requirements.txt (line 109)) (0.73.0)
# Requirement already satisfied: dataclasses==0.8 in /opt/conda/lib/python3.12/site-packages (from -r requirements.txt (line 110)) (0.8)
# Requirement already satisfied: dataclasses-json==0.6.7 in /opt/conda/lib/python3.12/site-packages (from -r requirements.txt (line 111)) (0.6.7)
# Requirement already satisfied: datasets==2.2.1 in /opt/conda/lib/python3.12/site-packages (from -r requirements.txt (line 112)) (2.2.1)
# Requirement already satisfied: debugpy==1.8.19 in /opt/conda/lib/python3.12/site-packages (from -r requirements.txt (line 113)) (1.8.19)
# Requirement already satisfied: decorator==5.2.1 in /opt/conda/lib/python3.12/site-packages (from -r requirements.txt (line 114)) (5.2.1)
# Requirement already satisfied: deepmerge==2.0 in /opt/conda/lib/python3.12/site-packages (from -r requirements.txt (line 115)) (2.0)
# Requirement already satisfied: defusedxml==0.7.1 in /opt/conda/lib/python3.12/site-packages (from -r requirements.txt (line 116)) (0.7.1)
# Requirement already satisfied: Deprecated==1.3.1 in /opt/conda/lib/python3.12/site-packages (from -r requirements.txt (line 117)) (1.3.1)
# Requirement already satisfied: dill==0.4.1 in /opt/conda/lib/python3.12/site-packages (from -r requirements.txt (line 118)) (0.4.1)
# Requirement already satisfied: diskcache==5.6.3 in /opt/conda/lib/python3.12/site-packages (from -r requirements.txt (line 119)) (5.6.3)
# Requirement already satisfied: distlib==0.4.0 in /opt/conda/lib/python3.12/site-packages (from -r requirements.txt (line 120)) (0.4.0)
# Requirement already satisfied: distributed==2026.1.1 in /opt/conda/lib/python3.12/site-packages (from -r requirements.txt (line 121)) (2026.1.1)
# Requirement already satisfied: distro==1.9.0 in /opt/conda/lib/python3.12/site-packages (from -r requirements.txt (line 122)) (1.9.0)
# Requirement already satisfied: dnspython==2.8.0 in /opt/conda/lib/python3.12/site-packages (from -r requirements.txt (line 123)) (2.8.0)
# Requirement already satisfied: docker==7.1.0 in /opt/conda/lib/python3.12/site-packages (from -r requirements.txt (line 124)) (7.1.0)
# Requirement already satisfied: docstring_parser==0.17.0 in /opt/conda/lib/python3.12/site-packages (from -r requirements.txt (line 125)) (0.17.0)
# Requirement already satisfied: docstring-to-markdown==0.17 in /opt/conda/lib/python3.12/site-packages (from -r requirements.txt (line 126)) (0.17)
# Requirement already satisfied: duckdb==1.4.3 in /opt/conda/lib/python3.12/site-packages (from -r requirements.txt (line 127)) (1.4.3)
# Collecting einx==0.3.0 (from -r requirements.txt (line 128))
#   Using cached einx-0.3.0-py3-none-any.whl.metadata (6.9 kB)
# Requirement already satisfied: email-validator==2.3.0 in /opt/conda/lib/python3.12/site-packages (from -r requirements.txt (line 129)) (2.3.0)
# Requirement already satisfied: entrypoints==0.4 in /opt/conda/lib/python3.12/site-packages (from -r requirements.txt (line 130)) (0.4)
# Requirement already satisfied: evaluate==0.4.1 in /opt/conda/lib/python3.12/site-packages (from -r requirements.txt (line 131)) (0.4.1)
# Requirement already satisfied: exceptiongroup==1.3.1 in /opt/conda/lib/python3.12/site-packages (from -r requirements.txt (line 132)) (1.3.1)
# Requirement already satisfied: executing==2.2.1 in /opt/conda/lib/python3.12/site-packages (from -r requirements.txt (line 133)) (2.2.1)
# Requirement already satisfied: faiss==1.9.0 in /opt/conda/lib/python3.12/site-packages (from -r requirements.txt (line 134)) (1.9.0)
# Collecting faiss-cpu==1.13.2 (from -r requirements.txt (line 135))
#   Using cached faiss_cpu-1.13.2-cp310-abi3-manylinux_2_27_x86_64.manylinux_2_28_x86_64.whl.metadata (7.6 kB)
# Requirement already satisfied: fastai==2.8.6 in /opt/conda/lib/python3.12/site-packages (from -r requirements.txt (line 136)) (2.8.6)
# Requirement already satisfied: fastapi==0.124.4 in /opt/conda/lib/python3.12/site-packages (from -r requirements.txt (line 137)) (0.124.4)
# Requirement already satisfied: fastapi-cli==0.0.20 in /opt/conda/lib/python3.12/site-packages (from -r requirements.txt (line 138)) (0.0.20)
# Requirement already satisfied: fastcore==1.12.5 in /opt/conda/lib/python3.12/site-packages (from -r requirements.txt (line 139)) (1.12.5)
# Requirement already satisfied: fastdownload==0.0.7 in /opt/conda/lib/python3.12/site-packages (from -r requirements.txt (line 140)) (0.0.7)
# Requirement already satisfied: fastjsonschema==2.21.2 in /opt/conda/lib/python3.12/site-packages (from -r requirements.txt (line 141)) (2.21.2)
# Requirement already satisfied: fastlite==0.2.3 in /opt/conda/lib/python3.12/site-packages (from -r requirements.txt (line 142)) (0.2.3)
# Requirement already satisfied: fastprogress==1.1.3 in /opt/conda/lib/python3.12/site-packages (from -r requirements.txt (line 143)) (1.1.3)
# Requirement already satisfied: fasttransform==0.0.2 in /opt/conda/lib/python3.12/site-packages (from -r requirements.txt (line 144)) (0.0.2)
# Requirement already satisfied: filelock==3.20.3 in /opt/conda/lib/python3.12/site-packages (from -r requirements.txt (line 145)) (3.20.3)
# Requirement already satisfied: flake8==7.1.2 in /opt/conda/lib/python3.12/site-packages (from -r requirements.txt (line 146)) (7.1.2)
# Collecting Flask==3.0.3 (from -r requirements.txt (line 147))
#   Using cached flask-3.0.3-py3-none-any.whl.metadata (3.2 kB)
# Requirement already satisfied: flatbuffers==25.9.23 in /opt/conda/lib/python3.12/site-packages (from -r requirements.txt (line 148)) (25.9.23)
# Requirement already satisfied: fonttools==4.61.1 in /opt/conda/lib/python3.12/site-packages (from -r requirements.txt (line 149)) (4.61.1)
# Requirement already satisfied: fqdn==1.5.1 in /opt/conda/lib/python3.12/site-packages (from -r requirements.txt (line 150)) (1.5.1)
# Requirement already satisfied: frozendict==2.4.7 in /opt/conda/lib/python3.12/site-packages (from -r requirements.txt (line 151)) (2.4.7)
# Requirement already satisfied: frozenlist==1.7.0 in /opt/conda/lib/python3.12/site-packages (from -r requirements.txt (line 152)) (1.7.0)
# Requirement already satisfied: fs==2.4.16 in /opt/conda/lib/python3.12/site-packages (from -r requirements.txt (line 153)) (2.4.16)
# Requirement already satisfied: fsspec==2024.12.0 in /opt/conda/lib/python3.12/site-packages (from -r requirements.txt (line 154)) (2024.12.0)
# Requirement already satisfied: fugue==0.9.4 in /opt/conda/lib/python3.12/site-packages (from -r requirements.txt (line 155)) (0.9.4)
# Requirement already satisfied: future==1.0.0 in /opt/conda/lib/python3.12/site-packages (from -r requirements.txt (line 156)) (1.0.0)
# Requirement already satisfied: gast==0.7.0 in /opt/conda/lib/python3.12/site-packages (from -r requirements.txt (line 157)) (0.7.0)
# Requirement already satisfied: gdown==5.2.1 in /opt/conda/lib/python3.12/site-packages (from -r requirements.txt (line 158)) (5.2.1)
# Requirement already satisfied: git-remote-codecommit==1.16 in /opt/conda/lib/python3.12/site-packages (from -r requirements.txt (line 159)) (1.16)
# Requirement already satisfied: gitdb==4.0.12 in /opt/conda/lib/python3.12/site-packages (from -r requirements.txt (line 160)) (4.0.12)
# Requirement already satisfied: GitPython==3.1.46 in /opt/conda/lib/python3.12/site-packages (from -r requirements.txt (line 161)) (3.1.46)
# Requirement already satisfied: gluonts==0.16.2 in /opt/conda/lib/python3.12/site-packages (from -r requirements.txt (line 162)) (0.16.2)
# Requirement already satisfied: gmpy2==2.2.1 in /opt/conda/lib/python3.12/site-packages (from -r requirements.txt (line 163)) (2.2.1)
# Requirement already satisfied: google-api-core==2.29.0 in /opt/conda/lib/python3.12/site-packages (from -r requirements.txt (line 164)) (2.29.0)
# Requirement already satisfied: google-auth==2.48.0 in /opt/conda/lib/python3.12/site-packages (from -r requirements.txt (line 165)) (2.48.0)
# Requirement already satisfied: google-cloud-bigquery==3.40.0 in /opt/conda/lib/python3.12/site-packages (from -r requirements.txt (line 166)) (3.40.0)
# Requirement already satisfied: google-cloud-core==2.5.0 in /opt/conda/lib/python3.12/site-packages (from -r requirements.txt (line 167)) (2.5.0)
# Requirement already satisfied: google-crc32c==1.8.0 in /opt/conda/lib/python3.12/site-packages (from -r requirements.txt (line 168)) (1.8.0)
# Requirement already satisfied: google-pasta==0.2.0 in /opt/conda/lib/python3.12/site-packages (from -r requirements.txt (line 169)) (0.2.0)
# Requirement already satisfied: google-resumable-media==2.8.0 in /opt/conda/lib/python3.12/site-packages (from -r requirements.txt (line 170)) (2.8.0)
# Requirement already satisfied: googleapis-common-protos==1.72.0 in /opt/conda/lib/python3.12/site-packages (from -r requirements.txt (line 171)) (1.72.0)
# Requirement already satisfied: graphene==3.4.3 in /opt/conda/lib/python3.12/site-packages (from -r requirements.txt (line 172)) (3.4.3)
# Requirement already satisfied: graphql-core==3.2.7 in /opt/conda/lib/python3.12/site-packages (from -r requirements.txt (line 173)) (3.2.7)
# Requirement already satisfied: graphql-relay==3.2.0 in /opt/conda/lib/python3.12/site-packages (from -r requirements.txt (line 174)) (3.2.0)
# Requirement already satisfied: graphviz==0.21 in /opt/conda/lib/python3.12/site-packages (from -r requirements.txt (line 175)) (0.21)
# Requirement already satisfied: greenlet==3.3.1 in /opt/conda/lib/python3.12/site-packages (from -r requirements.txt (line 176)) (3.3.1)
# Requirement already satisfied: grpcio==1.67.1 in /opt/conda/lib/python3.12/site-packages (from -r requirements.txt (line 177)) (1.67.1)
# Requirement already satisfied: grpcio-status==1.67.1 in /opt/conda/lib/python3.12/site-packages (from -r requirements.txt (line 178)) (1.67.1)
# Requirement already satisfied: gssapi==1.10.1 in /opt/conda/lib/python3.12/site-packages (from -r requirements.txt (line 179)) (1.10.1)
# Requirement already satisfied: gunicorn==23.0.0 in /opt/conda/lib/python3.12/site-packages (from -r requirements.txt (line 180)) (23.0.0)
# Requirement already satisfied: h11==0.16.0 in /opt/conda/lib/python3.12/site-packages (from -r requirements.txt (line 181)) (0.16.0)
# Requirement already satisfied: h2==4.3.0 in /opt/conda/lib/python3.12/site-packages (from -r requirements.txt (line 182)) (4.3.0)
# Requirement already satisfied: h5py==3.15.1 in /opt/conda/lib/python3.12/site-packages (from -r requirements.txt (line 183)) (3.15.1)
# Requirement already satisfied: hdijupyterutils==0.23.0 in /opt/conda/lib/python3.12/site-packages (from -r requirements.txt (line 184)) (0.23.0)
# Requirement already satisfied: hf-xet==1.2.1 in /opt/conda/lib/python3.12/site-packages (from -r requirements.txt (line 185)) (1.2.1)
# Requirement already satisfied: hpack==4.1.0 in /opt/conda/lib/python3.12/site-packages (from -r requirements.txt (line 186)) (4.1.0)
# Requirement already satisfied: httpcore==1.0.9 in /opt/conda/lib/python3.12/site-packages (from -r requirements.txt (line 187)) (1.0.9)
# Requirement already satisfied: httptools==0.7.1 in /opt/conda/lib/python3.12/site-packages (from -r requirements.txt (line 188)) (0.7.1)
# Requirement already satisfied: httpx==0.28.1 in /opt/conda/lib/python3.12/site-packages (from -r requirements.txt (line 189)) (0.28.1)
# Requirement already satisfied: httpx-sse==0.4.3 in /opt/conda/lib/python3.12/site-packages (from -r requirements.txt (line 190)) (0.4.3)
# Requirement already satisfied: huggingface_hub==0.36.0 in /opt/conda/lib/python3.12/site-packages (from -r requirements.txt (line 191)) (0.36.0)
# Requirement already satisfied: humanfriendly==10.0 in /opt/conda/lib/python3.12/site-packages (from -r requirements.txt (line 192)) (10.0)
# Requirement already satisfied: hyperframe==6.1.0 in /opt/conda/lib/python3.12/site-packages (from -r requirements.txt (line 193)) (6.1.0)
# Requirement already satisfied: hyperopt==0.2.7 in /opt/conda/lib/python3.12/site-packages (from -r requirements.txt (line 194)) (0.2.7)
# Requirement already satisfied: idna==3.11 in /opt/conda/lib/python3.12/site-packages (from -r requirements.txt (line 195)) (3.11)
# Requirement already satisfied: imagecodecs==2025.8.2 in /opt/conda/lib/python3.12/site-packages (from -r requirements.txt (line 196)) (2025.8.2)
# Requirement already satisfied: imageio==2.37.0 in /opt/conda/lib/python3.12/site-packages (from -r requirements.txt (line 197)) (2.37.0)
# Requirement already satisfied: importlib-metadata==6.10.0 in /opt/conda/lib/python3.12/site-packages (from -r requirements.txt (line 198)) (6.10.0)
# Requirement already satisfied: importlib_resources==6.5.2 in /opt/conda/lib/python3.12/site-packages (from -r requirements.txt (line 199)) (6.5.2)
# Requirement already satisfied: invoke==2.2.1 in /opt/conda/lib/python3.12/site-packages (from -r requirements.txt (line 200)) (2.2.1)
# Requirement already satisfied: ipykernel==7.1.0 in /opt/conda/lib/python3.12/site-packages (from -r requirements.txt (line 201)) (7.1.0)
# Requirement already satisfied: ipython==8.37.0 in /opt/conda/lib/python3.12/site-packages (from -r requirements.txt (line 202)) (8.37.0)
# Requirement already satisfied: ipywidgets==8.1.8 in /opt/conda/lib/python3.12/site-packages (from -r requirements.txt (line 203)) (8.1.8)
# Requirement already satisfied: isoduration==20.11.0 in /opt/conda/lib/python3.12/site-packages (from -r requirements.txt (line 204)) (20.11.0)
# Requirement already satisfied: isort==7.0.0 in /opt/conda/lib/python3.12/site-packages (from -r requirements.txt (line 205)) (7.0.0)
# Requirement already satisfied: itsdangerous==2.2.0 in /opt/conda/lib/python3.12/site-packages (from -r requirements.txt (line 206)) (2.2.0)
# Requirement already satisfied: jedi==0.19.2 in /opt/conda/lib/python3.12/site-packages (from -r requirements.txt (line 207)) (0.19.2)
# Requirement already satisfied: Jinja2==3.1.6 in /opt/conda/lib/python3.12/site-packages (from -r requirements.txt (line 208)) (3.1.6)
# Requirement already satisfied: jmespath==1.1.0 in /opt/conda/lib/python3.12/site-packages (from -r requirements.txt (line 209)) (1.1.0)
# Requirement already satisfied: joblib==1.5.3 in /opt/conda/lib/python3.12/site-packages (from -r requirements.txt (line 210)) (1.5.3)
# Requirement already satisfied: json5==0.13.0 in /opt/conda/lib/python3.12/site-packages (from -r requirements.txt (line 211)) (0.13.0)
# Requirement already satisfied: jsonpatch==1.33 in /opt/conda/lib/python3.12/site-packages (from -r requirements.txt (line 212)) (1.33)
# Requirement already satisfied: jsonpath-ng==1.7.0 in /opt/conda/lib/python3.12/site-packages (from -r requirements.txt (line 213)) (1.7.0)
# Requirement already satisfied: jsonpointer==3.0.0 in /opt/conda/lib/python3.12/site-packages (from -r requirements.txt (line 214)) (3.0.0)
# Requirement already satisfied: jsonschema==4.23.0 in /opt/conda/lib/python3.12/site-packages (from -r requirements.txt (line 215)) (4.23.0)
# Requirement already satisfied: jsonschema-specifications==2025.9.1 in /opt/conda/lib/python3.12/site-packages (from -r requirements.txt (line 216)) (2025.9.1)
# Requirement already satisfied: jupyter==1.1.1 in /opt/conda/lib/python3.12/site-packages (from -r requirements.txt (line 217)) (1.1.1)
# Requirement already satisfied: jupyter-activity-monitor-extension==0.3.2 in /opt/conda/lib/python3.12/site-packages (from -r requirements.txt (line 218)) (0.3.2)
# Requirement already satisfied: jupyter_ai==2.31.7 in /opt/conda/lib/python3.12/site-packages (from -r requirements.txt (line 219)) (2.31.7)
# Requirement already satisfied: jupyter_ai_magics==2.31.7 in /opt/conda/lib/python3.12/site-packages (from -r requirements.txt (line 220)) (2.31.7)
# Requirement already satisfied: jupyter_client==8.8.0 in /opt/conda/lib/python3.12/site-packages (from -r requirements.txt (line 221)) (8.8.0)
# Requirement already satisfied: jupyter-collaboration==3.1.2 in /opt/conda/lib/python3.12/site-packages (from -r requirements.txt (line 222)) (3.1.2)
# Requirement already satisfied: jupyter-collaboration-ui==1.1.2 in /opt/conda/lib/python3.12/site-packages (from -r requirements.txt (line 223)) (1.1.2)
# Requirement already satisfied: jupyter-console==6.6.3 in /opt/conda/lib/python3.12/site-packages (from -r requirements.txt (line 224)) (6.6.3)
# Requirement already satisfied: jupyter_core==5.9.1 in /opt/conda/lib/python3.12/site-packages (from -r requirements.txt (line 225)) (5.9.1)
# Requirement already satisfied: jupyter-dash==0.4.2 in /opt/conda/lib/python3.12/site-packages (from -r requirements.txt (line 226)) (0.4.2)
# Requirement already satisfied: jupyter-docprovider==1.1.2 in /opt/conda/lib/python3.12/site-packages (from -r requirements.txt (line 227)) (1.1.2)
# Requirement already satisfied: jupyter-events==0.12.0 in /opt/conda/lib/python3.12/site-packages (from -r requirements.txt (line 228)) (0.12.0)
# Requirement already satisfied: jupyter-lsp==2.3.0 in /opt/conda/lib/python3.12/site-packages (from -r requirements.txt (line 229)) (2.3.0)
# Requirement already satisfied: jupyter_scheduler==2.11.0 in /opt/conda/lib/python3.12/site-packages (from -r requirements.txt (line 230)) (2.11.0)
# Requirement already satisfied: jupyter_server==2.17.0 in /opt/conda/lib/python3.12/site-packages (from -r requirements.txt (line 231)) (2.17.0)
# Requirement already satisfied: jupyter_server_fileid==0.9.2 in /opt/conda/lib/python3.12/site-packages (from -r requirements.txt (line 232)) (0.9.2)
# Requirement already satisfied: jupyter_server_mathjax==0.2.6 in /opt/conda/lib/python3.12/site-packages (from -r requirements.txt (line 233)) (0.2.6)
# Requirement already satisfied: jupyter_server_proxy==4.4.0 in /opt/conda/lib/python3.12/site-packages (from -r requirements.txt (line 234)) (4.4.0)
# Requirement already satisfied: jupyter_server_terminals==0.5.4 in /opt/conda/lib/python3.12/site-packages (from -r requirements.txt (line 235)) (0.5.4)
# Requirement already satisfied: jupyter-server-ydoc==1.1.2 in /opt/conda/lib/python3.12/site-packages (from -r requirements.txt (line 236)) (1.1.2)
# Requirement already satisfied: jupyter-ydoc==3.3.4 in /opt/conda/lib/python3.12/site-packages (from -r requirements.txt (line 237)) (3.3.4)
# Requirement already satisfied: jupyterlab==4.4.10 in /opt/conda/lib/python3.12/site-packages (from -r requirements.txt (line 238)) (4.4.10)
# Requirement already satisfied: jupyterlab_git==0.51.4 in /opt/conda/lib/python3.12/site-packages (from -r requirements.txt (line 239)) (0.51.4)
# Requirement already satisfied: jupyterlab-lsp==5.0.3 in /opt/conda/lib/python3.12/site-packages (from -r requirements.txt (line 240)) (5.0.3)
# Requirement already satisfied: jupyterlab_pygments==0.3.0 in /opt/conda/lib/python3.12/site-packages (from -r requirements.txt (line 241)) (0.3.0)
# Requirement already satisfied: jupyterlab_server==2.28.0 in /opt/conda/lib/python3.12/site-packages (from -r requirements.txt (line 242)) (2.28.0)
# Requirement already satisfied: jupyterlab_widgets==3.0.16 in /opt/conda/lib/python3.12/site-packages (from -r requirements.txt (line 243)) (3.0.16)
# Collecting kagglehub==1.0.0 (from -r requirements.txt (line 244))
#   Using cached kagglehub-1.0.0-py3-none-any.whl.metadata (40 kB)
# Collecting kagglesdk==0.1.15 (from -r requirements.txt (line 245))
#   Using cached kagglesdk-0.1.15-py3-none-any.whl.metadata (13 kB)
# Requirement already satisfied: keras==3.12.0 in /opt/conda/lib/python3.12/site-packages (from -r requirements.txt (line 246)) (3.12.0)
# Requirement already satisfied: kiwisolver==1.4.9 in /opt/conda/lib/python3.12/site-packages (from -r requirements.txt (line 247)) (1.4.9)
# Requirement already satisfied: krb5==0.5.1 in /opt/conda/lib/python3.12/site-packages (from -r requirements.txt (line 248)) (0.5.1)
# Requirement already satisfied: langchain==0.3.27 in /opt/conda/lib/python3.12/site-packages (from -r requirements.txt (line 249)) (0.3.27)
# Collecting langchain-aws==0.2.18 (from -r requirements.txt (line 250))
#   Using cached langchain_aws-0.2.18-py3-none-any.whl.metadata (3.2 kB)
# Requirement already satisfied: langchain-community==0.3.31 in /opt/conda/lib/python3.12/site-packages (from -r requirements.txt (line 251)) (0.3.31)
# Requirement already satisfied: langchain-core==0.3.81 in /opt/conda/lib/python3.12/site-packages (from -r requirements.txt (line 252)) (0.3.81)
# Requirement already satisfied: langchain-text-splitters==0.3.11 in /opt/conda/lib/python3.12/site-packages (from -r requirements.txt (line 253)) (0.3.11)
# Requirement already satisfied: langsmith==0.6.5 in /opt/conda/lib/python3.12/site-packages (from -r requirements.txt (line 254)) (0.6.5)
# Requirement already satisfied: lazy_loader==0.4 in /opt/conda/lib/python3.12/site-packages (from -r requirements.txt (line 255)) (0.4)
# Requirement already satisfied: libmambapy==2.3.2 in /opt/conda/lib/python3.12/site-packages (from -r requirements.txt (line 256)) (2.3.2)
# Requirement already satisfied: lightgbm==4.6.0 in /opt/conda/lib/python3.12/site-packages (from -r requirements.txt (line 257)) (4.6.0)
# Requirement already satisfied: lightning==2.6.0 in /opt/conda/lib/python3.12/site-packages (from -r requirements.txt (line 258)) (2.6.0)
# Requirement already satisfied: lightning-utilities==0.15.2 in /opt/conda/lib/python3.12/site-packages (from -r requirements.txt (line 259)) (0.15.2)
# Requirement already satisfied: llvmlite==0.46.0 in /opt/conda/lib/python3.12/site-packages (from -r requirements.txt (line 260)) (0.46.0)
# Requirement already satisfied: locket==1.0.0 in /opt/conda/lib/python3.12/site-packages (from -r requirements.txt (line 261)) (1.0.0)
# Collecting loguru==0.7.3 (from -r requirements.txt (line 262))
#   Using cached loguru-0.7.3-py3-none-any.whl.metadata (22 kB)
# Requirement already satisfied: lxml==5.4.0 in /opt/conda/lib/python3.12/site-packages (from -r requirements.txt (line 263)) (5.4.0)
# Requirement already satisfied: Mako==1.3.10 in /opt/conda/lib/python3.12/site-packages (from -r requirements.txt (line 264)) (1.3.10)
# Requirement already satisfied: Markdown==3.10.1 in /opt/conda/lib/python3.12/site-packages (from -r requirements.txt (line 265)) (3.10.1)
# Requirement already satisfied: markdown-it-py==4.0.0 in /opt/conda/lib/python3.12/site-packages (from -r requirements.txt (line 266)) (4.0.0)
# Requirement already satisfied: MarkupSafe==3.0.3 in /opt/conda/lib/python3.12/site-packages (from -r requirements.txt (line 267)) (3.0.3)
# Requirement already satisfied: marshmallow==3.26.1 in /opt/conda/lib/python3.12/site-packages (from -r requirements.txt (line 268)) (3.26.1)
# Requirement already satisfied: matplotlib==3.10.8 in /opt/conda/lib/python3.12/site-packages (from -r requirements.txt (line 269)) (3.10.8)
# Requirement already satisfied: matplotlib-inline==0.2.1 in /opt/conda/lib/python3.12/site-packages (from -r requirements.txt (line 270)) (0.2.1)
# Requirement already satisfied: mccabe==0.7.0 in /opt/conda/lib/python3.12/site-packages (from -r requirements.txt (line 271)) (0.7.0)
# Requirement already satisfied: mcp==1.23.3 in /opt/conda/lib/python3.12/site-packages (from -r requirements.txt (line 272)) (1.23.3)
# Requirement already satisfied: mdurl==0.1.2 in /opt/conda/lib/python3.12/site-packages (from -r requirements.txt (line 273)) (0.1.2)
# Requirement already satisfied: menuinst==2.4.2 in /opt/conda/lib/python3.12/site-packages (from -r requirements.txt (line 274)) (2.4.2)
# Requirement already satisfied: mistune==3.2.0 in /opt/conda/lib/python3.12/site-packages (from -r requirements.txt (line 275)) (3.2.0)
# Requirement already satisfied: ml-dtypes==0.4.0 in /opt/conda/lib/python3.12/site-packages (from -r requirements.txt (line 276)) (0.4.0)
# Requirement already satisfied: mlflow==2.22.0 in /opt/conda/lib/python3.12/site-packages (from -r requirements.txt (line 277)) (2.22.0)
# Requirement already satisfied: mlflow-skinny==2.22.0 in /opt/conda/lib/python3.12/site-packages (from -r requirements.txt (line 278)) (2.22.0)
# Requirement already satisfied: mlforecast==0.14.0 in /opt/conda/lib/python3.12/site-packages (from -r requirements.txt (line 279)) (0.14.0)
# Requirement already satisfied: mmh3==5.2.0 in /opt/conda/lib/python3.12/site-packages (from -r requirements.txt (line 280)) (5.2.0)
# Requirement already satisfied: mock==4.0.3 in /opt/conda/lib/python3.12/site-packages (from -r requirements.txt (line 281)) (4.0.3)
# Requirement already satisfied: model-index==0.1.11 in /opt/conda/lib/python3.12/site-packages (from -r requirements.txt (line 282)) (0.1.11)
# Requirement already satisfied: mpmath==1.3.0 in /opt/conda/lib/python3.12/site-packages (from -r requirements.txt (line 283)) (1.3.0)
# Requirement already satisfied: msgpack==1.1.2 in /opt/conda/lib/python3.12/site-packages (from -r requirements.txt (line 284)) (1.1.2)
# Requirement already satisfied: multidict==6.7.0 in /opt/conda/lib/python3.12/site-packages (from -r requirements.txt (line 285)) (6.7.0)
# Requirement already satisfied: multiprocess==0.70.19 in /opt/conda/lib/python3.12/site-packages (from -r requirements.txt (line 286)) (0.70.19)
# Requirement already satisfied: munkres==1.1.4 in /opt/conda/lib/python3.12/site-packages (from -r requirements.txt (line 287)) (1.1.4)
# Requirement already satisfied: murmurhash==1.0.15 in /opt/conda/lib/python3.12/site-packages (from -r requirements.txt (line 288)) (1.0.15)
# Requirement already satisfied: mypy_extensions==1.1.0 in /opt/conda/lib/python3.12/site-packages (from -r requirements.txt (line 289)) (1.1.0)
# Requirement already satisfied: namex==0.1.0 in /opt/conda/lib/python3.12/site-packages (from -r requirements.txt (line 290)) (0.1.0)
# Requirement already satisfied: narwhals==2.15.0 in /opt/conda/lib/python3.12/site-packages (from -r requirements.txt (line 291)) (2.15.0)
# Requirement already satisfied: nbclient==0.10.4 in /opt/conda/lib/python3.12/site-packages (from -r requirements.txt (line 292)) (0.10.4)
# Requirement already satisfied: nbconvert==7.16.6 in /opt/conda/lib/python3.12/site-packages (from -r requirements.txt (line 293)) (7.16.6)
# Requirement already satisfied: nbdime==4.0.3 in /opt/conda/lib/python3.12/site-packages (from -r requirements.txt (line 294)) (4.0.3)
# Requirement already satisfied: nbformat==5.10.4 in /opt/conda/lib/python3.12/site-packages (from -r requirements.txt (line 295)) (5.10.4)
# Requirement already satisfied: nest_asyncio==1.6.0 in /opt/conda/lib/python3.12/site-packages (from -r requirements.txt (line 296)) (1.6.0)
# Requirement already satisfied: networkx==3.6.1 in /opt/conda/lib/python3.12/site-packages (from -r requirements.txt (line 297)) (3.6.1)
# Requirement already satisfied: nlpaug==1.1.11 in /opt/conda/lib/python3.12/site-packages (from -r requirements.txt (line 298)) (1.1.11)
# Requirement already satisfied: nltk==3.9.2 in /opt/conda/lib/python3.12/site-packages (from -r requirements.txt (line 299)) (3.9.2)
# Requirement already satisfied: nose==1.3.7 in /opt/conda/lib/python3.12/site-packages (from -r requirements.txt (line 300)) (1.3.7)
# Requirement already satisfied: notebook==7.4.7 in /opt/conda/lib/python3.12/site-packages (from -r requirements.txt (line 301)) (7.4.7)
# Requirement already satisfied: notebook_shim==0.2.4 in /opt/conda/lib/python3.12/site-packages (from -r requirements.txt (line 302)) (0.2.4)
# Requirement already satisfied: numba==0.63.1 in /opt/conda/lib/python3.12/site-packages (from -r requirements.txt (line 303)) (0.63.1)
# Requirement already satisfied: numpy==1.26.4 in /opt/conda/lib/python3.12/site-packages (from -r requirements.txt (line 304)) (1.26.4)
# Collecting nvidia-ml-py3==7.352.0 (from -r requirements.txt (line 305))
#   Using cached nvidia_ml_py3-7.352.0-py3-none-any.whl
# Requirement already satisfied: oauthlib==3.3.1 in /opt/conda/lib/python3.12/site-packages (from -r requirements.txt (line 306)) (3.3.1)
# Requirement already satisfied: omegaconf==2.3.0 in /opt/conda/lib/python3.12/site-packages (from -r requirements.txt (line 307)) (2.3.0)
# Requirement already satisfied: onnxruntime==1.22.2 in /opt/conda/lib/python3.12/site-packages (from -r requirements.txt (line 308)) (1.22.2)
# Requirement already satisfied: opencensus==0.11.3 in /opt/conda/lib/python3.12/site-packages (from -r requirements.txt (line 309)) (0.11.3)
# Requirement already satisfied: opencensus-context==0.1.3 in /opt/conda/lib/python3.12/site-packages (from -r requirements.txt (line 310)) (0.1.3)
# Collecting opencv-python-headless (from -r requirements.txt (line 2))
#   Using cached opencv_python_headless-4.11.0.86-cp37-abi3-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (20 kB)
# Requirement already satisfied: openmim==0.3.7 in /opt/conda/lib/python3.12/site-packages (from -r requirements.txt (line 312)) (0.3.7)
# Requirement already satisfied: opentelemetry-api==1.39.1 in /opt/conda/lib/python3.12/site-packages (from -r requirements.txt (line 313)) (1.39.1)
# Requirement already satisfied: opentelemetry-instrumentation==0.60b1 in /opt/conda/lib/python3.12/site-packages (from -r requirements.txt (line 314)) (0.60b1)
# Requirement already satisfied: opentelemetry-instrumentation-threading==0.60b1 in /opt/conda/lib/python3.12/site-packages (from -r requirements.txt (line 315)) (0.60b1)
# Requirement already satisfied: opentelemetry-sdk==1.39.1 in /opt/conda/lib/python3.12/site-packages (from -r requirements.txt (line 316)) (1.39.1)
# Requirement already satisfied: opentelemetry-semantic-conventions==0.60b1 in /opt/conda/lib/python3.12/site-packages (from -r requirements.txt (line 317)) (0.60b1)
# Requirement already satisfied: opt_einsum==3.4.0 in /opt/conda/lib/python3.12/site-packages (from -r requirements.txt (line 318)) (3.4.0)
# Requirement already satisfied: optree==0.18.0 in /opt/conda/lib/python3.12/site-packages (from -r requirements.txt (line 319)) (0.18.0)
# Requirement already satisfied: optuna==4.7.0 in /opt/conda/lib/python3.12/site-packages (from -r requirements.txt (line 320)) (4.7.0)
# Requirement already satisfied: ordered-set==4.1.0 in /opt/conda/lib/python3.12/site-packages (from -r requirements.txt (line 321)) (4.1.0)
# Requirement already satisfied: orjson==3.11.5 in /opt/conda/lib/python3.12/site-packages (from -r requirements.txt (line 322)) (3.11.5)
# Requirement already satisfied: overrides==7.7.0 in /opt/conda/lib/python3.12/site-packages (from -r requirements.txt (line 323)) (7.7.0)
# Requirement already satisfied: packaging==24.2 in /opt/conda/lib/python3.12/site-packages (from -r requirements.txt (line 324)) (24.2)
# Requirement already satisfied: pandas==2.3.3 in /opt/conda/lib/python3.12/site-packages (from -r requirements.txt (line 325)) (2.3.3)
# Requirement already satisfied: pandocfilters==1.5.0 in /opt/conda/lib/python3.12/site-packages (from -r requirements.txt (line 326)) (1.5.0)
# Requirement already satisfied: papermill==2.6.0 in /opt/conda/lib/python3.12/site-packages (from -r requirements.txt (line 327)) (2.6.0)
# Requirement already satisfied: paramiko==4.0.0 in /opt/conda/lib/python3.12/site-packages (from -r requirements.txt (line 328)) (4.0.0)
# Requirement already satisfied: parso==0.8.5 in /opt/conda/lib/python3.12/site-packages (from -r requirements.txt (line 329)) (0.8.5)
# Requirement already satisfied: partd==1.4.2 in /opt/conda/lib/python3.12/site-packages (from -r requirements.txt (line 330)) (1.4.2)
# Requirement already satisfied: pathos==0.3.5 in /opt/conda/lib/python3.12/site-packages (from -r requirements.txt (line 331)) (0.3.5)
# Requirement already satisfied: pathspec==1.0.3 in /opt/conda/lib/python3.12/site-packages (from -r requirements.txt (line 332)) (1.0.3)
# Requirement already satisfied: patsy==1.0.2 in /opt/conda/lib/python3.12/site-packages (from -r requirements.txt (line 333)) (1.0.2)
# Requirement already satisfied: pdf2image==1.17.0 in /opt/conda/lib/python3.12/site-packages (from -r requirements.txt (line 334)) (1.17.0)
# Requirement already satisfied: pexpect==4.9.0 in /opt/conda/lib/python3.12/site-packages (from -r requirements.txt (line 335)) (4.9.0)
# Requirement already satisfied: pickleshare==0.7.5 in /opt/conda/lib/python3.12/site-packages (from -r requirements.txt (line 336)) (0.7.5)
# Requirement already satisfied: pillow==11.3.0 in /opt/conda/lib/python3.12/site-packages (from -r requirements.txt (line 337)) (11.3.0)
# Requirement already satisfied: pip==25.3 in /opt/conda/lib/python3.12/site-packages (from -r requirements.txt (line 338)) (25.3)
# Requirement already satisfied: pkgutil_resolve_name==1.3.10 in /opt/conda/lib/python3.12/site-packages (from -r requirements.txt (line 339)) (1.3.10)
# Requirement already satisfied: platformdirs==4.5.1 in /opt/conda/lib/python3.12/site-packages (from -r requirements.txt (line 340)) (4.5.1)
# Requirement already satisfied: plotly==6.0.1 in /opt/conda/lib/python3.12/site-packages (from -r requirements.txt (line 341)) (6.0.1)
# Requirement already satisfied: pluggy==1.6.0 in /opt/conda/lib/python3.12/site-packages (from -r requirements.txt (line 342)) (1.6.0)
# Requirement already satisfied: plum-dispatch==2.6.1 in /opt/conda/lib/python3.12/site-packages (from -r requirements.txt (line 343)) (2.6.1)
# Requirement already satisfied: ply==3.11 in /opt/conda/lib/python3.12/site-packages (from -r requirements.txt (line 344)) (3.11)
# ...
# Requirement already satisfied: strands-agents-tools==0.1.9 in /opt/conda/lib/python3.12/site-packages (from -r requirements.txt (line 490)) (0.1.9)
# Requirement already satisfied: strictyaml==1.7.3 in /opt/conda/lib/python3.12/site-packages (from -r requirements.txt (line 491)) (1.7.3)
# Collecting stringzilla==4.6.0 (from -r requirements.txt (line 492))
#   Using cached stringzilla-4.6.0-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.manylinux_2_28_x86_64.whl.metadata (121 kB)
# Requirement already satisfied: supervisor==4.2.5 in /opt/conda/lib/python3.12/site-packages (from -r requirements.txt (line 493)) (4.2.5)
# Requirement already satisfied: sympy==1.14.0 in /opt/conda/lib/python3.12/site-packages (from -r requirements.txt (line 494)) (1.14.0)
# Requirement already satisfied: tabulate==0.9.0 in /opt/conda/lib/python3.12/site-packages (from -r requirements.txt (line 495)) (0.9.0)
# Requirement already satisfied: tblib==3.2.2 in /opt/conda/lib/python3.12/site-packages (from -r requirements.txt (line 496)) (3.2.2)
# Requirement already satisfied: tenacity==9.1.2 in /opt/conda/lib/python3.12/site-packages (from -r requirements.txt (line 497)) (9.1.2)
# Requirement already satisfied: tensorboard==2.18.0 in /opt/conda/lib/python3.12/site-packages (from -r requirements.txt (line 498)) (2.18.0)
# Requirement already satisfied: tensorboard_data_server==0.7.0 in /opt/conda/lib/python3.12/site-packages (from -r requirements.txt (line 499)) (0.7.0)
# Requirement already satisfied: tensorboardX==2.6.2.2 in /opt/conda/lib/python3.12/site-packages (from -r requirements.txt (line 500)) (2.6.2.2)
# Requirement already satisfied: tensorflow==2.18.0 in /opt/conda/lib/python3.12/site-packages (from -r requirements.txt (line 501)) (2.18.0)
# Requirement already satisfied: tensorflow_estimator==2.15.0 in /opt/conda/lib/python3.12/site-packages (from -r requirements.txt (line 502)) (2.15.0)
# Requirement already satisfied: termcolor==3.3.0 in /opt/conda/lib/python3.12/site-packages (from -r requirements.txt (line 503)) (3.3.0)
# Requirement already satisfied: terminado==0.18.1 in /opt/conda/lib/python3.12/site-packages (from -r requirements.txt (line 504)) (0.18.1)
# Requirement already satisfied: text-unidecode==1.3 in /opt/conda/lib/python3.12/site-packages (from -r requirements.txt (line 505)) (1.3)
# Requirement already satisfied: tf_keras==2.18.0 in /opt/conda/lib/python3.12/site-packages (from -r requirements.txt (line 506)) (2.18.0)
# Requirement already satisfied: thinc==8.3.10 in /opt/conda/lib/python3.12/site-packages (from -r requirements.txt (line 507)) (8.3.10)
# Requirement already satisfied: threadpoolctl==3.6.0 in /opt/conda/lib/python3.12/site-packages (from -r requirements.txt (line 508)) (3.6.0)
# Requirement already satisfied: thrift==0.22.0 in /opt/conda/lib/python3.12/site-packages (from -r requirements.txt (line 509)) (0.22.0)
# Requirement already satisfied: thrift_sasl==0.4.3 in /opt/conda/lib/python3.12/site-packages (from -r requirements.txt (line 510)) (0.4.3)
# Requirement already satisfied: tifffile==2025.12.12 in /opt/conda/lib/python3.12/site-packages (from -r requirements.txt (line 511)) (2025.12.12)
# Requirement already satisfied: timm==1.0.3 in /opt/conda/lib/python3.12/site-packages (from -r requirements.txt (line 512)) (1.0.3)
# Collecting tinycss2==1.4.0 (from -r requirements.txt (line 513))
#   Using cached tinycss2-1.4.0-py3-none-any.whl.metadata (3.0 kB)
# Collecting tokenizers==0.21.4 (from -r requirements.txt (line 514))
#   Using cached tokenizers-0.21.4-cp39-abi3-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (6.7 kB)
# Requirement already satisfied: tomli==2.4.0 in /opt/conda/lib/python3.12/site-packages (from -r requirements.txt (line 515)) (2.4.0)
# Requirement already satisfied: tomlkit==0.14.0 in /opt/conda/lib/python3.12/site-packages (from -r requirements.txt (line 516)) (0.14.0)
# Requirement already satisfied: toolz==0.12.1 in /opt/conda/lib/python3.12/site-packages (from -r requirements.txt (line 517)) (0.12.1)
# Requirement already satisfied: torch==2.6.0 in /opt/conda/lib/python3.12/site-packages (from -r requirements.txt (line 518)) (2.6.0)
# Requirement already satisfied: torchmetrics==1.7.4 in /opt/conda/lib/python3.12/site-packages (from -r requirements.txt (line 519)) (1.7.4)
# Requirement already satisfied: torchvision==0.21.0 in /opt/conda/lib/python3.12/site-packages (from -r requirements.txt (line 520)) (0.21.0)
# Requirement already satisfied: torchvision-extra-decoders==0.0.2 in /opt/conda/lib/python3.12/site-packages (from -r requirements.txt (line 521)) (0.0.2)
# Requirement already satisfied: tornado==6.5.4 in /opt/conda/lib/python3.12/site-packages (from -r requirements.txt (line 522)) (6.5.4)
# Requirement already satisfied: tqdm==4.67.1 in /opt/conda/lib/python3.12/site-packages (from -r requirements.txt (line 523)) (4.67.1)
# Requirement already satisfied: traitlets==5.14.3 in /opt/conda/lib/python3.12/site-packages (from -r requirements.txt (line 524)) (5.14.3)
# Collecting transformers==4.49.0 (from -r requirements.txt (line 525))
#   Using cached transformers-4.49.0-py3-none-any.whl.metadata (44 kB)
# Requirement already satisfied: triad==1.0.0 in /opt/conda/lib/python3.12/site-packages (from -r requirements.txt (line 526)) (1.0.0)
# Requirement already satisfied: truststore==0.10.4 in /opt/conda/lib/python3.12/site-packages (from -r requirements.txt (line 527)) (0.10.4)
# Requirement already satisfied: typer==0.21.1 in /opt/conda/lib/python3.12/site-packages (from -r requirements.txt (line 528)) (0.21.1)
# Requirement already satisfied: typer-slim==0.21.1 in /opt/conda/lib/python3.12/site-packages (from -r requirements.txt (line 529)) (0.21.1)
# Requirement already satisfied: typing_extensions==4.15.0 in /opt/conda/lib/python3.12/site-packages (from -r requirements.txt (line 530)) (4.15.0)
# Requirement already satisfied: typing_inspect==0.9.0 in /opt/conda/lib/python3.12/site-packages (from -r requirements.txt (line 531)) (0.9.0)
# Requirement already satisfied: typing-inspection==0.4.2 in /opt/conda/lib/python3.12/site-packages (from -r requirements.txt (line 532)) (0.4.2)
# Requirement already satisfied: typing_utils==0.1.0 in /opt/conda/lib/python3.12/site-packages (from -r requirements.txt (line 533)) (0.1.0)
# Requirement already satisfied: tzdata==2025.3 in /opt/conda/lib/python3.12/site-packages (from -r requirements.txt (line 534)) (2025.3)
# Requirement already satisfied: ujson==5.11.0 in /opt/conda/lib/python3.12/site-packages (from -r requirements.txt (line 535)) (5.11.0)
# Requirement already satisfied: unicodedata2==17.0.0 in /opt/conda/lib/python3.12/site-packages (from -r requirements.txt (line 536)) (17.0.0)
# Requirement already satisfied: uri-template==1.3.0 in /opt/conda/lib/python3.12/site-packages (from -r requirements.txt (line 537)) (1.3.0)
# Requirement already satisfied: urllib3==1.26.20 in /opt/conda/lib/python3.12/site-packages (from -r requirements.txt (line 538)) (1.26.20)
# Requirement already satisfied: utilsforecast==0.2.11 in /opt/conda/lib/python3.12/site-packages (from -r requirements.txt (line 539)) (0.2.11)
# Requirement already satisfied: uuid_utils==0.13.0 in /opt/conda/lib/python3.12/site-packages (from -r requirements.txt (line 540)) (0.13.0)
# Requirement already satisfied: uvicorn==0.38.0 in /opt/conda/lib/python3.12/site-packages (from -r requirements.txt (line 541)) (0.38.0)
# Requirement already satisfied: uvloop==0.22.1 in /opt/conda/lib/python3.12/site-packages (from -r requirements.txt (line 542)) (0.22.1)
# Requirement already satisfied: virtualenv==20.36.1 in /opt/conda/lib/python3.12/site-packages (from -r requirements.txt (line 543)) (20.36.1)
# Requirement already satisfied: wasabi==1.1.3 in /opt/conda/lib/python3.12/site-packages (from -r requirements.txt (line 544)) (1.1.3)
# Requirement already satisfied: watchdog==6.0.0 in /opt/conda/lib/python3.12/site-packages (from -r requirements.txt (line 545)) (6.0.0)
# Requirement already satisfied: watchfiles==1.1.1 in /opt/conda/lib/python3.12/site-packages (from -r requirements.txt (line 546)) (1.1.1)
# Requirement already satisfied: wcwidth==0.5.0 in /opt/conda/lib/python3.12/site-packages (from -r requirements.txt (line 547)) (0.5.0)
# Requirement already satisfied: weasel==0.4.3 in /opt/conda/lib/python3.12/site-packages (from -r requirements.txt (line 548)) (0.4.3)
# Requirement already satisfied: webcolors==25.10.0 in /opt/conda/lib/python3.12/site-packages (from -r requirements.txt (line 549)) (25.10.0)
# Requirement already satisfied: webencodings==0.5.1 in /opt/conda/lib/python3.12/site-packages (from -r requirements.txt (line 550)) (0.5.1)
# Requirement already satisfied: websocket-client==1.9.0 in /opt/conda/lib/python3.12/site-packages (from -r requirements.txt (line 551)) (1.9.0)
# Requirement already satisfied: websockets==16.0 in /opt/conda/lib/python3.12/site-packages (from -r requirements.txt (line 552)) (16.0)
# Collecting Werkzeug==3.0.6 (from -r requirements.txt (line 553))
#   Using cached werkzeug-3.0.6-py3-none-any.whl.metadata (3.7 kB)
# Requirement already satisfied: whatthepatch==1.0.7 in /opt/conda/lib/python3.12/site-packages (from -r requirements.txt (line 554)) (1.0.7)
# Requirement already satisfied: wheel==0.46.3 in /opt/conda/lib/python3.12/site-packages (from -r requirements.txt (line 555)) (0.46.3)
# Requirement already satisfied: widgetsnbextension==4.0.15 in /opt/conda/lib/python3.12/site-packages (from -r requirements.txt (line 556)) (4.0.15)
# Requirement already satisfied: window_ops==0.0.15 in /opt/conda/lib/python3.12/site-packages (from -r requirements.txt (line 557)) (0.0.15)
# Requirement already satisfied: wrapt==1.17.3 in /opt/conda/lib/python3.12/site-packages (from -r requirements.txt (line 558)) (1.17.3)
# Requirement already satisfied: xgboost==2.1.4 in /opt/conda/lib/python3.12/site-packages (from -r requirements.txt (line 559)) (2.1.4)
# Requirement already satisfied: xxhash==3.6.0 in /opt/conda/lib/python3.12/site-packages (from -r requirements.txt (line 560)) (3.6.0)
# Requirement already satisfied: y-py==0.6.2 in /opt/conda/lib/python3.12/site-packages (from -r requirements.txt (line 561)) (0.6.2)
# Requirement already satisfied: yapf==0.43.0 in /opt/conda/lib/python3.12/site-packages (from -r requirements.txt (line 562)) (0.43.0)
# Requirement already satisfied: yarl==1.22.0 in /opt/conda/lib/python3.12/site-packages (from -r requirements.txt (line 563)) (1.22.0)
# Requirement already satisfied: ypy-websocket==0.12.4 in /opt/conda/lib/python3.12/site-packages (from -r requirements.txt (line 564)) (0.12.4)
# Requirement already satisfied: zict==3.0.0 in /opt/conda/lib/python3.12/site-packages (from -r requirements.txt (line 565)) (3.0.0)
# Requirement already satisfied: zipp==3.23.0 in /opt/conda/lib/python3.12/site-packages (from -r requirements.txt (line 566)) (3.23.0)
# Requirement already satisfied: zstandard==0.25.0 in /opt/conda/lib/python3.12/site-packages (from -r requirements.txt (line 567)) (0.25.0)
# Using cached albumentations-2.0.8-py3-none-any.whl (369 kB)
# Using cached opencv_python_headless-4.11.0.86-cp37-abi3-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (50.0 MB)
# Using cached albucore-0.0.24-py3-none-any.whl (15 kB)
# Using cached faiss_cpu-1.13.2-cp310-abi3-manylinux_2_27_x86_64.manylinux_2_28_x86_64.whl (23.8 MB)
# Using cached transformers-4.49.0-py3-none-any.whl (10.0 MB)
# Using cached tokenizers-0.21.4-cp39-abi3-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (3.1 MB)
# Using cached flask-3.0.3-py3-none-any.whl (101 kB)
# Using cached werkzeug-3.0.6-py3-none-any.whl (227 kB)
# Using cached dash_core_components-2.0.0-py3-none-any.whl (3.8 kB)
# Using cached dash_html_components-2.0.0-py3-none-any.whl (4.1 kB)
# Using cached dash_table-5.0.0-py3-none-any.whl (3.9 kB)
# Using cached protobuf-5.29.6-cp38-abi3-manylinux2014_x86_64.whl (320 kB)
# Using cached einx-0.3.0-py3-none-any.whl (102 kB)
# Using cached kagglehub-1.0.0-py3-none-any.whl (70 kB)
# Using cached kagglesdk-0.1.15-py3-none-any.whl (160 kB)
# Using cached langchain_aws-0.2.18-py3-none-any.whl (118 kB)
# Using cached loguru-0.7.3-py3-none-any.whl (61 kB)
# Using cached pycocotools-2.0.11-cp312-abi3-manylinux2014_x86_64.manylinux_2_17_x86_64.manylinux_2_28_x86_64.whl (411 kB)
# Using cached pynacl-1.6.0-cp38-abi3-manylinux_2_34_x86_64.whl (1.4 MB)
# Using cached simsimd-6.5.12-cp312-cp312-manylinux2014_x86_64.manylinux_2_17_x86_64.manylinux_2_28_x86_64.whl (582 kB)
# Using cached stringzilla-4.6.0-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.manylinux_2_28_x86_64.whl (2.1 MB)
# Using cached tinycss2-1.4.0-py3-none-any.whl (26 kB)
# Installing collected packages: simsimd, nvidia-ml-py3, dash-table, dash-html-components, dash-core-components, Werkzeug, tinycss2, stringzilla, pycocotools, protobuf, opencv-python-headless, loguru, faiss-cpu, PyNaCl, kagglesdk, Flask, einx, albucore, tokenizers, kagglehub, albumentations, transformers, langchain-aws, sparkmagic
#   Attempting uninstall: Werkzeug
#     Found existing installation: Werkzeug 3.1.5
#     Uninstalling Werkzeug-3.1.5:
#       Successfully uninstalled Werkzeug-3.1.5
#   Attempting uninstall: tinycss290m━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━  5/24 [Werkzeug]
#     Found existing installation: tinycss2 1.5.1━━━━━━━━━━━━━━━  5/24 [Werkzeug]
#     Uninstalling tinycss2-1.5.1:━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━  5/24 [Werkzeug]
#       Successfully uninstalled tinycss2-1.5.1━━━━━━━━━━━━━━━━━  5/24 [Werkzeug]
#   Attempting uninstall: protobufm━━━━━━━━━━━━━━━━━━━━━━━━━━━━  7/24 [stringzilla]
#     Found existing installation: protobuf 5.28.3━━━━━━━━━━━━━━  7/24 [stringzilla]
#     Uninstalling protobuf-5.28.3:m━━━━━━━━━━━━━━━━━━━━━━━━━━━━  7/24 [stringzilla]
#       Successfully uninstalled protobuf-5.28.3━━━━━━━━━━━━━━━━  7/24 [stringzilla]
#   Attempting uninstall: PyNaCl0m╺━━━━━━━━━━━━━━━━━━━ 12/24 [faiss-cpu]hon-headless]
#     Found existing installation: PyNaCl 1.6.2━━━━━━━━━━━━━━━━━ 12/24 [faiss-cpu]
#     Uninstalling PyNaCl-1.6.2:90m╺━━━━━━━━━━━━━━━━━━━ 12/24 [faiss-cpu]
#       Successfully uninstalled PyNaCl-1.6.2━━━━━━━━━━━━━━━━━━━ 12/24 [faiss-cpu]
#   Attempting uninstall: Flask━━╺━━━━━━━━━━━━━━━━ 14/24 [kagglesdk]
#     Found existing installation: Flask 3.1.20m━━━━━━━━━━━━━━━━ 14/24 [kagglesdk]
#     Uninstalling Flask-3.1.2:0m╺━━━━━━━━━━━━━━━━ 14/24 [kagglesdk]
#       Successfully uninstalled Flask-3.1.2━━━━━━━━━━━━━━━━ 14/24 [kagglesdk]
#   Attempting uninstall: tokenizers━━╺━━━━━━━━━━━ 17/24 [albucore]
#     Found existing installation: tokenizers 0.22.2m━━━━━━━━━━━ 17/24 [albucore]
#     Uninstalling tokenizers-0.22.2:m╺━━━━━━━━━━━ 17/24 [albucore]
#       Successfully uninstalled tokenizers-0.22.290m━━━━━━━━━━━ 17/24 [albucore]
#   Attempting uninstall: transformers━━━━━╺━━━━━━ 20/24 [albumentations]
#     Found existing installation: transformers 4.57.6━━━━━━ 20/24 [albumentations]
#     Uninstalling transformers-4.57.6:━━━━━━╺━━━━ 21/24 [transformers]
#       Successfully uninstalled transformers-4.57.60m╺━━━━ 21/24 [transformers]
#   Attempting uninstall: langchain-aws━━━━━━╺━━━━ 21/24 [transformers]
#     Found existing installation: langchain-aws 0.2.19━━━━ 21/24 [transformers]
#     Uninstalling langchain-aws-0.2.19:━╺━━━━ 21/24 [transformers]
#       Successfully uninstalled langchain-aws-0.2.190m━━━━ 21/24 [transformers]
#   Attempting uninstall: sparkmagic━━━━━╺━━━━ 21/24 [transformers]
#     Found existing installation: sparkmagic 0.21.0━━━━ 21/24 [transformers]
#     Uninstalling sparkmagic-0.21.0:━━━━╺━━━━ 21/24 [transformers]
#       Successfully uninstalled sparkmagic-0.21.0╺━━━━ 21/24 [transformers]
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 24/24 [sparkmagic]4 [sparkmagic]
# Successfully installed Flask-3.0.3 PyNaCl-1.6.0 Werkzeug-3.0.6 albucore-0.0.24 albumentations-2.0.8 dash-core-components-2.0.0 dash-html-components-2.0.0 dash-table-5.0.0 einx-0.3.0 faiss-cpu-1.13.2 kagglehub-1.0.0 kagglesdk-0.1.15 langchain-aws-0.2.18 loguru-0.7.3 nvidia-ml-py3-7.352.0 opencv-python-headless-4.11.0.86 protobuf-5.29.6 pycocotools-2.0.11 simsimd-6.5.12 sparkmagic-0.22.0 stringzilla-4.6.0 tinycss2-1.4.0 tokenizers-0.21.4 transformers-4.49.0

# %%
setup_dependencies_passed = True

# %%
# %store setup_dependencies_passed
# Out:
# Stored 'setup_dependencies_passed' (bool)

# %% [markdown]
# ## Create S3 bucket

# %%
import boto3
from botocore.client import ClientError
import sagemaker

session = boto3.session.Session()
region = session.region_name
sagemaker_session = sagemaker.Session()
bucket = sagemaker_session.default_bucket()

s3 = boto3.Session().client(service_name="s3", region_name=region)
# Out:
# sagemaker.config INFO - Not applying SDK defaults from location: /etc/xdg/sagemaker/config.yaml
# sagemaker.config INFO - Not applying SDK defaults from location: /home/sagemaker-user/.config/sagemaker/config.yaml

# %%
setup_s3_bucket_passed = False

# %%
print("Default bucket: {}".format(bucket))
# Out:
# Default bucket: sagemaker-us-east-1-567266240490

# %% [markdown]
# ## Verifying bucket

# %%
response = None

try:
    response = s3.head_bucket(Bucket=bucket)
    print(response)
    setup_s3_bucket_passed = True
except ClientError as e:
    print("[ERROR] Cannot find bucket {} in {} due to {}.".format(bucket, response, e))
# Out:
# {'ResponseMetadata': {'RequestId': 'FTJKVT9S44C1FZVF', 'HostId': 'EH7E4SXQtWINBDC3tcrrWmS9ysIzZyP9BuDJIYECzdM/mXdwVgVjfrXne0EYSCVusNPO/MZzqJ1tJNC3aQXlZac1qcYrFUGo', 'HTTPStatusCode': 200, 'HTTPHeaders': {'x-amz-id-2': 'EH7E4SXQtWINBDC3tcrrWmS9ysIzZyP9BuDJIYECzdM/mXdwVgVjfrXne0EYSCVusNPO/MZzqJ1tJNC3aQXlZac1qcYrFUGo', 'x-amz-request-id': 'FTJKVT9S44C1FZVF', 'date': 'Tue, 17 Feb 2026 00:12:47 GMT', 'x-amz-bucket-region': 'us-east-1', 'x-amz-access-point-alias': 'false', 'x-amz-bucket-arn': 'arn:aws:s3:::sagemaker-us-east-1-567266240490', 'content-type': 'application/xml', 'transfer-encoding': 'chunked', 'server': 'AmazonS3'}, 'RetryAttempts': 0}, 'BucketRegion': 'us-east-1', 'AccessPointAlias': False}

# %%
# %store setup_s3_bucket_passed
# Out:
# Stored 'setup_s3_bucket_passed' (bool)

# %%
# %store
# Out:
# Stored variables and their in-db values:
# bucket                                                 -> 'sagemaker-us-east-1-567266240490'
# database_name                                          -> 'cat_landmarking'
# ingest_create_athena_db_passed                         -> True
# ingest_create_athena_image_combined_passed             -> True
# ingestion_completed                                    -> True
# landmarks_feature_group_name                           -> 'landmarks-feature-group-16-19-21-33'
# landmarks_table                                        -> 'cat_annotations'
# manifest_table                                         -> 'image_manifest'
# project_prefix                                         -> 'cat-landmarks-project'
# s3_athena_results_dir                                  -> 's3://sagemaker-us-east-1-567266240490/cat-landmar
# s3_processed_cats_prefix                               -> 's3://sagemaker-us-east-1-567266240490/cat-landmar
# s3_processed_combined_prefix                           -> 's3://sagemaker-us-east-1-567266240490/cat-landmar
# s3_raw_cats_prefix                                     -> 's3://sagemaker-us-east-1-567266240490/cat-landmar
# s3_raw_noncats_prefix                                  -> 's3://sagemaker-us-east-1-567266240490/cat-landmar
# s3_staging_dir                                         -> 's3://sagemaker-us-east-1-567266240490/cat-landmar
# setup_dependencies_passed                              -> True
# setup_s3_bucket_passed                                 -> True
